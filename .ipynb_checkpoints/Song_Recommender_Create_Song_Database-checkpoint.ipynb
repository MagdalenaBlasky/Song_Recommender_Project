# %%
import config

# %%
import pandas as pd
import spotipy
import json
import pprint
from spotipy.oauth2 import SpotifyClientCredentials

sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id= config.client_id,
                                                           client_secret= config.client_secret))

# %%
def get_playlist_tracks(username, playlist_id):
    results = sp.user_playlist_tracks(username,playlist_id,market="GB")
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks

# %%
#this function creates a dataframe from a given playlist - the arguments are playlist_ID and user_name of the creator.

def create_df_with_audio_features (playlist_id,username): 
    
    '''as arguments pass a spotify playlist id and the corresponding user name. 
    the function returns a dataframe with audiofeatures of all songs from given playlist.'''
    
    def get_playlist_tracks(username, playlist_id):
        
        '''this function returns list of dictionaries where each dictionary is one song'''
        
        results = sp.user_playlist_tracks(username,playlist_id,market="GB")
        tracks = results['items']
        while results['next']:
            results = sp.next(results)
            tracks.extend(results['items'])
        return tracks
    
    tracks = get_playlist_tracks(username, playlist_id)
    
    track_id_list = []

    for p in range (len(tracks)):
        track_id_list.append(tracks[p]['track']["id"])
    
    audio_features = sp.audio_features(track_id_list) # this function takes maximum of 100 id's
    
    songs_dataframe = pd.DataFrame(audio_features)
    
    return songs_dataframe

# %%
#this function uses a dictionary of playlists to add new songs to an existing dataframe

def create_data_frame_from_multiple_dataframes(playlist_id_and_username_dict, songs_audio_features_df):
    
    '''as arguments pass a dictionary where keys are playlist ids and values are usernames 
    and an existing data frame of song audio features'''
    
    for key, value in playlist_id_and_username_dict.items():
        x = create_df_with_audio_features(key,value)
        songs_audio_features_df = pd.concat(objs=[songs_audio_features_df, x], axis=0,ignore_index=True)
        
    songs_audio_features_df.to_csv("Data/songs_audio_feature_dataframe1.csv", index=False)
                               
    return songs_audio_features_df

# %%
x = create_data_frame_from_multiple_dataframes(playlist_dict_2,x)
x
# Out:
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0            0.708   0.566   11   -10.142     0       0.0362      0.000127
# 1            0.710   0.625    5   -15.300     0       0.0414      0.004180
# 2            0.716   0.783    4   -12.876     0       0.0496      0.172000
# 3            0.742   0.756   10    -6.197     1       0.0825      0.021300
# 4            0.726   0.907    5    -5.009     0       0.0894      0.000916
# ...            ...     ...  ...       ...   ...          ...           ...
# 1834         0.699   0.869    9   -10.199     1       0.0456      0.031700
# 1835         0.883   0.333    5   -17.848     0       0.0530      0.007990
# 1836         0.707   0.654    5   -12.209     0       0.0588      0.011300
# 1837         0.646   0.770    7    -6.243     1       0.0325      0.066800
# 1838         0.836   0.626    9   -10.143     0       0.0335      0.094300
#
#       instrumentalness  liveness  valence    tempo            type  \
# 0             0.033800    0.2900    0.731  121.997  audio_features
# 1             0.935000    0.1090    0.183  124.876  audio_features
# 2             0.034600    0.0327    0.952  121.306  audio_features
# 3             0.022700    0.0553    0.810  129.963  audio_features
# 4             0.000521    0.2170    0.498  124.841  audio_features
# ...                ...       ...      ...      ...             ...
# 1834          0.411000    0.0368    0.963  115.273  audio_features
# 1835          0.804000    0.2570    0.964  121.099  audio_features
# 1836          0.001730    0.0677    0.834  104.964  audio_features
# 1837          0.112000    0.4030    0.869  100.334  audio_features
# 1838          0.742000    0.1530    0.898  114.657  audio_features
#
#                           id                                   uri  \
# 0     0ilZMeXHPKDPjUc4Neu04f  spotify:track:0ilZMeXHPKDPjUc4Neu04f
# 1     0ZBPWoRkfZ8SLcDJaFnkUu  spotify:track:0ZBPWoRkfZ8SLcDJaFnkUu
# 2     5sJiLlgQKBL81QCTOkoLB5  spotify:track:5sJiLlgQKBL81QCTOkoLB5
# 3     0TN9m8rp3ZuNi4JwCKSans  spotify:track:0TN9m8rp3ZuNi4JwCKSans
# 4     2FrCwt008k0xqtCFH1VaTZ  spotify:track:2FrCwt008k0xqtCFH1VaTZ
# ...                      ...                                   ...
# 1834  1np1H7mh6iUZhdBhkh3QIo  spotify:track:1np1H7mh6iUZhdBhkh3QIo
# 1835  2mCLc4lZjbpcpXgNBrC5lY  spotify:track:2mCLc4lZjbpcpXgNBrC5lY
# 1836  6p3IJixqlLe4ya2pFf4Yjq  spotify:track:6p3IJixqlLe4ya2pFf4Yjq
# 1837  1ZnQFc3ifkHA1sdBGFO2EL  spotify:track:1ZnQFc3ifkHA1sdBGFO2EL
# 1838  58r4JuwHhXLAkttkaUZfLw  spotify:track:58r4JuwHhXLAkttkaUZfLw
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/0ilZMeXHPKDP...
# 1     https://api.spotify.com/v1/tracks/0ZBPWoRkfZ8S...
# 2     https://api.spotify.com/v1/tracks/5sJiLlgQKBL8...
# 3     https://api.spotify.com/v1/tracks/0TN9m8rp3ZuN...
# 4     https://api.spotify.com/v1/tracks/2FrCwt008k0x...
# ...                                                 ...
# 1834  https://api.spotify.com/v1/tracks/1np1H7mh6iUZ...
# 1835  https://api.spotify.com/v1/tracks/2mCLc4lZjbpc...
# 1836  https://api.spotify.com/v1/tracks/6p3IJixqlLe4...
# 1837  https://api.spotify.com/v1/tracks/1ZnQFc3ifkHA...
# 1838  https://api.spotify.com/v1/tracks/58r4JuwHhXLA...
#
#                                            analysis_url  duration_ms  \
# 0     https://api.spotify.com/v1/audio-analysis/0ilZ...       416027
# 1     https://api.spotify.com/v1/audio-analysis/0ZBP...       262400
# 2     https://api.spotify.com/v1/audio-analysis/5sJi...       244773
# 3     https://api.spotify.com/v1/audio-analysis/0TN9...       484533
# 4     https://api.spotify.com/v1/audio-analysis/2FrC...       369067
# ...                                                 ...          ...
# 1834  https://api.spotify.com/v1/audio-analysis/1np1...       416800
# 1835  https://api.spotify.com/v1/audio-analysis/2mCL...       382015
# 1836  https://api.spotify.com/v1/audio-analysis/6p3I...       453427
# 1837  https://api.spotify.com/v1/audio-analysis/1ZnQ...       321773
# 1838  https://api.spotify.com/v1/audio-analysis/58r4...       307947
#
#       time_signature
# 0                  4
# 1                  4
# 2                  4
# 3                  4
# 4                  4
# ...              ...
# 1834               4
# 1835               4
# 1836               4
# 1837               4
# 1838               4
#
# [1839 rows x 18 columns]

# %%
xyz = create_data_frame_from_multiple_dataframes(new_dict,z)
xyz
# Out:
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.7080  0.5660   11   -10.142     0       0.0362      0.000127
# 1           0.7100  0.6250    5   -15.300     0       0.0414      0.004180
# 2           0.7160  0.7830    4   -12.876     0       0.0496      0.172000
# 3           0.7420  0.7560   10    -6.197     1       0.0825      0.021300
# 4           0.7260  0.9070    5    -5.009     0       0.0894      0.000916
# ...            ...     ...  ...       ...   ...          ...           ...
# 2439        0.1870  0.0615    7   -25.725     0       0.0363      0.590000
# 2440        0.5380  0.4270   11   -15.665     0       0.0250      0.321000
# 2441        0.3780  0.5040    3   -16.948     1       0.0366      0.630000
# 2442        0.0988  0.0505    2   -25.516     0       0.0500      0.912000
# 2443        0.1520  0.0296    8   -26.521     1       0.0518      0.879000
#
#       instrumentalness  liveness  valence    tempo            type  \
# 0             0.033800    0.2900   0.7310  121.997  audio_features
# 1             0.935000    0.1090   0.1830  124.876  audio_features
# 2             0.034600    0.0327   0.9520  121.306  audio_features
# 3             0.022700    0.0553   0.8100  129.963  audio_features
# 4             0.000521    0.2170   0.4980  124.841  audio_features
# ...                ...       ...      ...      ...             ...
# 2439          0.927000    0.1120   0.0267   70.569  audio_features
# 2440          0.830000    0.1160   0.1450  106.015  audio_features
# 2441          0.847000    0.0854   0.0387  158.024  audio_features
# 2442          0.924000    0.0891   0.0334   74.455  audio_features
# 2443          0.867000    0.1410   0.0391  137.706  audio_features
#
#                           id                                   uri  \
# 0     0ilZMeXHPKDPjUc4Neu04f  spotify:track:0ilZMeXHPKDPjUc4Neu04f
# 1     0ZBPWoRkfZ8SLcDJaFnkUu  spotify:track:0ZBPWoRkfZ8SLcDJaFnkUu
# 2     5sJiLlgQKBL81QCTOkoLB5  spotify:track:5sJiLlgQKBL81QCTOkoLB5
# 3     0TN9m8rp3ZuNi4JwCKSans  spotify:track:0TN9m8rp3ZuNi4JwCKSans
# 4     2FrCwt008k0xqtCFH1VaTZ  spotify:track:2FrCwt008k0xqtCFH1VaTZ
# ...                      ...                                   ...
# 2439  5gWWrtrpTtFSORAI9Gh9cx  spotify:track:5gWWrtrpTtFSORAI9Gh9cx
# 2440  6rBPxpqvZbcKm9RL4UCptg  spotify:track:6rBPxpqvZbcKm9RL4UCptg
# 2441  6YLykcAuyOaNt4K6vXj4l2  spotify:track:6YLykcAuyOaNt4K6vXj4l2
# 2442  1sM9n4jthKx2C98z0ONCyc  spotify:track:1sM9n4jthKx2C98z0ONCyc
# 2443  5oJRZUtuCVUyG9M9B5IwpG  spotify:track:5oJRZUtuCVUyG9M9B5IwpG
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/0ilZMeXHPKDP...
# 1     https://api.spotify.com/v1/tracks/0ZBPWoRkfZ8S...
# 2     https://api.spotify.com/v1/tracks/5sJiLlgQKBL8...
# 3     https://api.spotify.com/v1/tracks/0TN9m8rp3ZuN...
# 4     https://api.spotify.com/v1/tracks/2FrCwt008k0x...
# ...                                                 ...
# 2439  https://api.spotify.com/v1/tracks/5gWWrtrpTtFS...
# 2440  https://api.spotify.com/v1/tracks/6rBPxpqvZbcK...
# 2441  https://api.spotify.com/v1/tracks/6YLykcAuyOaN...
# 2442  https://api.spotify.com/v1/tracks/1sM9n4jthKx2...
# 2443  https://api.spotify.com/v1/tracks/5oJRZUtuCVUy...
#
#                                            analysis_url  duration_ms  \
# 0     https://api.spotify.com/v1/audio-analysis/0ilZ...       416027
# 1     https://api.spotify.com/v1/audio-analysis/0ZBP...       262400
# 2     https://api.spotify.com/v1/audio-analysis/5sJi...       244773
# 3     https://api.spotify.com/v1/audio-analysis/0TN9...       484533
# 4     https://api.spotify.com/v1/audio-analysis/2FrC...       369067
# ...                                                 ...          ...
# 2439  https://api.spotify.com/v1/audio-analysis/5gWW...        91377
# 2440  https://api.spotify.com/v1/audio-analysis/6rBP...       136879
# 2441  https://api.spotify.com/v1/audio-analysis/6YLy...       156204
# 2442  https://api.spotify.com/v1/audio-analysis/1sM9...       144031
# 2443  https://api.spotify.com/v1/audio-analysis/5oJR...        66199
#
#       time_signature
# 0                  4
# 1                  4
# 2                  4
# 3                  4
# 4                  4
# ...              ...
# 2439               3
# 2440               4
# 2441               4
# 2442               4
# 2443               4
#
# [2444 rows x 18 columns]

# %%
z
# Out:
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0            0.708   0.566   11   -10.142     0       0.0362      0.000127
# 1            0.710   0.625    5   -15.300     0       0.0414      0.004180
# 2            0.716   0.783    4   -12.876     0       0.0496      0.172000
# 3            0.742   0.756   10    -6.197     1       0.0825      0.021300
# 4            0.726   0.907    5    -5.009     0       0.0894      0.000916
# ...            ...     ...  ...       ...   ...          ...           ...
# 2344         0.678   0.680    0    -6.990     0       0.0442      0.397000
# 2345         0.735   0.885    8    -9.863     0       0.0364      0.042600
# 2346         0.696   0.626    1    -5.633     0       0.0541      0.525000
# 2347         0.718   0.721    1    -6.712     0       0.0398      0.180000
# 2348         0.748   0.588    4    -9.711     1       0.0488      0.341000
#
#       instrumentalness  liveness  valence    tempo            type  \
# 0             0.033800    0.2900    0.731  121.997  audio_features
# 1             0.935000    0.1090    0.183  124.876  audio_features
# 2             0.034600    0.0327    0.952  121.306  audio_features
# 3             0.022700    0.0553    0.810  129.963  audio_features
# 4             0.000521    0.2170    0.498  124.841  audio_features
# ...                ...       ...      ...      ...             ...
# 2344          0.836000    0.5190    0.686  119.978  audio_features
# 2345          0.829000    0.0819    0.566  119.018  audio_features
# 2346          0.000000    0.2720    0.567  104.940  audio_features
# 2347          0.010800    0.3060    0.154  117.915  audio_features
# 2348          0.000094    0.2430    0.680  114.963  audio_features
#
#                           id                                   uri  \
# 0     0ilZMeXHPKDPjUc4Neu04f  spotify:track:0ilZMeXHPKDPjUc4Neu04f
# 1     0ZBPWoRkfZ8SLcDJaFnkUu  spotify:track:0ZBPWoRkfZ8SLcDJaFnkUu
# 2     5sJiLlgQKBL81QCTOkoLB5  spotify:track:5sJiLlgQKBL81QCTOkoLB5
# 3     0TN9m8rp3ZuNi4JwCKSans  spotify:track:0TN9m8rp3ZuNi4JwCKSans
# 4     2FrCwt008k0xqtCFH1VaTZ  spotify:track:2FrCwt008k0xqtCFH1VaTZ
# ...                      ...                                   ...
# 2344  2ddVNzU2kTrs9VLiuurU9C  spotify:track:2ddVNzU2kTrs9VLiuurU9C
# 2345  5HzFIsnKHQzt7hkIxGDy1D  spotify:track:5HzFIsnKHQzt7hkIxGDy1D
# 2346  49AmxcPnsET8xC6vJWSsbo  spotify:track:49AmxcPnsET8xC6vJWSsbo
# 2347  2KUuZ8IEeH6kEBVf7PQvsi  spotify:track:2KUuZ8IEeH6kEBVf7PQvsi
# 2348  7dKYUSJXp0FWmEyon1Iwxr  spotify:track:7dKYUSJXp0FWmEyon1Iwxr
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/0ilZMeXHPKDP...
# 1     https://api.spotify.com/v1/tracks/0ZBPWoRkfZ8S...
# 2     https://api.spotify.com/v1/tracks/5sJiLlgQKBL8...
# 3     https://api.spotify.com/v1/tracks/0TN9m8rp3ZuN...
# 4     https://api.spotify.com/v1/tracks/2FrCwt008k0x...
# ...                                                 ...
# 2344  https://api.spotify.com/v1/tracks/2ddVNzU2kTrs...
# 2345  https://api.spotify.com/v1/tracks/5HzFIsnKHQzt...
# 2346  https://api.spotify.com/v1/tracks/49AmxcPnsET8...
# 2347  https://api.spotify.com/v1/tracks/2KUuZ8IEeH6k...
# 2348  https://api.spotify.com/v1/tracks/7dKYUSJXp0FW...
#
#                                            analysis_url  duration_ms  \
# 0     https://api.spotify.com/v1/audio-analysis/0ilZ...       416027
# 1     https://api.spotify.com/v1/audio-analysis/0ZBP...       262400
# 2     https://api.spotify.com/v1/audio-analysis/5sJi...       244773
# 3     https://api.spotify.com/v1/audio-analysis/0TN9...       484533
# 4     https://api.spotify.com/v1/audio-analysis/2FrC...       369067
# ...                                                 ...          ...
# 2344  https://api.spotify.com/v1/audio-analysis/2ddV...       134005
# 2345  https://api.spotify.com/v1/audio-analysis/5HzF...       183092
# 2346  https://api.spotify.com/v1/audio-analysis/49Am...       178286
# 2347  https://api.spotify.com/v1/audio-analysis/2KUu...       144407
# 2348  https://api.spotify.com/v1/audio-analysis/7dKY...       119217
#
#       time_signature
# 0                  4
# 1                  4
# 2                  4
# 3                  4
# 4                  4
# ...              ...
# 2344               4
# 2345               4
# 2346               4
# 2347               4
# 2348               4
#
# [2349 rows x 18 columns]

# %%
#example of an error

playlist_dict_6_electronic = {'37i9dQZF1DXbXD9pMSZomS':'Spotify'}

z = create_data_frame_from_multiple_dataframes(playlist_dict_6_electronic,z)
z
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [194], in <module>
#       1 playlist_dict_6_electronic = {'37i9dQZF1DXbXD9pMSZomS':'Spotify'}
# ----> 3 z = create_data_frame_from_multiple_dataframes(playlist_dict_6_electronic,z)
#       4 z
#
# Input In [193], in create_data_frame_from_multiple_dataframes(playlist_id_and_username_dict, songs_audio_features_df)
#       5 '''as arguments pass a dictionary where keys are playlist ids and values are usernames
#       6 and an existing data frame of song audio features'''
#       8 for key, value in playlist_id_and_username_dict.items():
# ----> 9     x = create_df_with_audio_features(key,value)
#      10     songs_audio_features_df = pd.concat(objs=[songs_audio_features_df, x], axis=0,ignore_index=True)
#      12 songs_audio_features_df.to_csv("Data/songs_audio_feature_dataframe")
#
# Input In [185], in create_df_with_audio_features(playlist_id, username)
#      24     track_id_list.append(tracks[p]['track']["id"])
#      26 audio_features = sp.audio_features(track_id_list) # this function takes maximum of 100 id's
# ---> 28 songs_dataframe = pd.DataFrame(audio_features)
#      30 return songs_dataframe
#
# File ~/opt/anaconda3/envs/DA_Env/lib/python3.9/site-packages/pandas/core/frame.py:694, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     689     if columns is not None:
#     690         # error: Argument 1 to "ensure_index" has incompatible type
#     691         # "Collection[Any]"; expected "Union[Union[Union[ExtensionArray,
#     692         # ndarray], Index, Series], Sequence[Any]]"
#     693         columns = ensure_index(columns)  # type: ignore[arg-type]
# --> 694     arrays, columns, index = nested_data_to_arrays(
#     695         # error: Argument 3 to "nested_data_to_arrays" has incompatible
#     696         # type "Optional[Collection[Any]]"; expected "Optional[Index]"
#     697         data,
#     698         columns,
#     699         index,  # type: ignore[arg-type]
#     700         dtype,
#     701     )
#     702     mgr = arrays_to_mgr(
#     703         arrays,
#     704         columns,
#    (...)
#     708         typ=manager,
#     709     )
#     710 else:
#
# File ~/opt/anaconda3/envs/DA_Env/lib/python3.9/site-packages/pandas/core/internals/construction.py:483, in nested_data_to_arrays(data, columns, index, dtype)
#     480 if is_named_tuple(data[0]) and columns is None:
#     481     columns = ensure_index(data[0]._fields)
# --> 483 arrays, columns = to_arrays(data, columns, dtype=dtype)
#     484 columns = ensure_index(columns)
#     486 if index is None:
#
# File ~/opt/anaconda3/envs/DA_Env/lib/python3.9/site-packages/pandas/core/internals/construction.py:799, in to_arrays(data, columns, dtype)
#     797     arr = _list_to_arrays(data)
#     798 elif isinstance(data[0], abc.Mapping):
# --> 799     arr, columns = _list_of_dict_to_arrays(data, columns)
#     800 elif isinstance(data[0], ABCSeries):
#     801     arr, columns = _list_of_series_to_arrays(data, columns)
#
# File ~/opt/anaconda3/envs/DA_Env/lib/python3.9/site-packages/pandas/core/internals/construction.py:884, in _list_of_dict_to_arrays(data, columns)
#     882     gen = (list(x.keys()) for x in data)
#     883     sort = not any(isinstance(d, dict) for d in data)
# --> 884     pre_cols = lib.fast_unique_multiple_list_gen(gen, sort=sort)
#     885     columns = ensure_index(pre_cols)
#     887 # assure that they are of the base dict class and not of derived
#     888 # classes
#
# File ~/opt/anaconda3/envs/DA_Env/lib/python3.9/site-packages/pandas/_libs/lib.pyx:400, in pandas._libs.lib.fast_unique_multiple_list_gen()
#
# File ~/opt/anaconda3/envs/DA_Env/lib/python3.9/site-packages/pandas/core/internals/construction.py:882, in <genexpr>(.0)
#     862 """
#     863 Convert list of dicts to numpy arrays
#     864
#    (...)
#     879 columns : Index
#     880 """
#     881 if columns is None:
# --> 882     gen = (list(x.keys()) for x in data)
#     883     sort = not any(isinstance(d, dict) for d in data)
#     884     pre_cols = lib.fast_unique_multiple_list_gen(gen, sort=sort)
#
# AttributeError: 'NoneType' object has no attribute 'keys'

# %%
hiphop_dictionary = {"37i9dQZF1DX2XmsXL2WBQd" : "Spotify"}
punk_dictionary = {"37i9dQZF1DXd6tJtr4qeot" : "Spotify"}
punk2 = {"37i9dQZF1EQqlvxWrOgFZm" : "Spotify" , "37i9dQZF1DX3MU5XUozve7": "Spotify"}
pop_hits = {'37i9dQZF1DWX7rdRjOECPW':'Spotify','37i9dQZF1DX3WvGXE8FqYX':'Spotify','37i9dQZF1DWWvoJqVv7uOD':'Spotify','37i9dQZF1DX7C2BlYJgCS5':'Spotify','37i9dQZF1DX2cNqJ4LgCMf':'Spotify','37i9dQZF1DX0s5kDXi1oC5':'Spotify','37i9dQZF1DXbYM3nMM0oPk':'Spotify'}
top_hits = {'37i9dQZEVXbMDoHDwVN2tF':'Spotify','37i9dQZF1ELYYzWaAD67i5':'Spotify','37i9dQZF1Etapvneoc5oia':'Spotify','37i9dQZF1DWUZv12GM5cFk':'Spotify','37i9dQZF1DXe2bobNYDtW8':'Spotify','37i9dQZF1Ejg7HCBbS3gRp':'Spotify'}
velvey_dict_5 = {'6l1RZerhJ0PF2Cnc9kivMp':'velvey','18V3QFlzjSbqyqAloYo3kh':'velvey'}
kk_1 = {'0KJUi7mAOTsUePrdX6r0ox':'Krzysztof Kwiatkowski','14qXDJrwuulLf3exANLFoO':'Krzysztof Kwiatkowski','0aqp4lz9ycEYQvN10gAUIa':'Krzysztof Kwiatkowski','1p280xCnCPO4PFpVfcgq98':'Krzysztof Kwiatkowski','33NMaOSGPBjd3LIBLr4pAE':'Krzysztof Kwiatkowski'}
kk_2 = {'23PD93UC3JGg9o9U6UyeJz':'Krzysztof Kwiatkowski','1UVmaFVxuikDCQV6SdlZFG':'Krzysztof Kwiatkowski','3LXBcw9KcSlLT1o2AtDgFg':'Krzysztof Kwiatkowski','4Smw6f7rJzvP6mKn1HJ2rG':'Krzysztof Kwiatkowski','63VD8EO5G5fVWJNh6FMCyW':'Krzysztof Kwiatkowski'}

# %%
#find audio features for user input

def find_features_input():
    user_input = input("Please enter a song name here: ")
    x = sp.search(q="user_song",limit=1,market="GB")['tracks']['items'][0]['external_urls']['spotify'][31:]
    y = sp.audio_features(x)
    #make the format of the data frame the sme as our song list (+ standardize with standard scaler)
    return pd.DataFrame(y)

# %%
songs_audio_features_dataframe = xyz.drop_duplicates(ignore_index = True)

# %%
#dataframe after dropping duplicates 

songs_audio_features_dataframe
# Out:
#        danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0             0.708   0.566   11   -10.142     0       0.0362      0.000127
# 1             0.710   0.625    5   -15.300     0       0.0414      0.004180
# 2             0.716   0.783    4   -12.876     0       0.0496      0.172000
# 3             0.742   0.756   10    -6.197     1       0.0825      0.021300
# 4             0.726   0.907    5    -5.009     0       0.0894      0.000916
# ...             ...     ...  ...       ...   ...          ...           ...
# 10265         0.378   0.665    2   -11.604     1       0.0352      0.020300
# 10266         0.123   0.785    0    -2.621     1       0.0638      0.000001
# 10267         0.527   0.293    0   -16.701     0       0.1320      0.669000
# 10268         0.498   0.995    3    -6.110     0       0.0493      0.008020
# 10269         0.186   0.125   10   -25.139     0       0.0504      0.201000
#
#        instrumentalness  liveness  valence    tempo            type  \
# 0              0.033800    0.2900    0.731  121.997  audio_features
# 1              0.935000    0.1090    0.183  124.876  audio_features
# 2              0.034600    0.0327    0.952  121.306  audio_features
# 3              0.022700    0.0553    0.810  129.963  audio_features
# 4              0.000521    0.2170    0.498  124.841  audio_features
# ...                 ...       ...      ...      ...             ...
# 10265          0.858000    0.3180    0.512  110.074  audio_features
# 10266          0.757000    0.3980    0.139  169.221  audio_features
# 10267          0.841000    0.1040    0.127  105.008  audio_features
# 10268          0.177000    0.2210    0.339  148.241  audio_features
# 10269          0.865000    0.1070    0.038   67.928  audio_features
#
#                            id                                   uri  \
# 0      0ilZMeXHPKDPjUc4Neu04f  spotify:track:0ilZMeXHPKDPjUc4Neu04f
# 1      0ZBPWoRkfZ8SLcDJaFnkUu  spotify:track:0ZBPWoRkfZ8SLcDJaFnkUu
# 2      5sJiLlgQKBL81QCTOkoLB5  spotify:track:5sJiLlgQKBL81QCTOkoLB5
# 3      0TN9m8rp3ZuNi4JwCKSans  spotify:track:0TN9m8rp3ZuNi4JwCKSans
# 4      2FrCwt008k0xqtCFH1VaTZ  spotify:track:2FrCwt008k0xqtCFH1VaTZ
# ...                       ...                                   ...
# 10265  2x0eC3SRcTwvGJxoXvhfcE  spotify:track:2x0eC3SRcTwvGJxoXvhfcE
# 10266  0339v0PaMmnpb7IOdGgnvJ  spotify:track:0339v0PaMmnpb7IOdGgnvJ
# 10267  4XjW9fcihP29h7fBAvXlDe  spotify:track:4XjW9fcihP29h7fBAvXlDe
# 10268  2yr8zjsYtBAeZwpvQYC66k  spotify:track:2yr8zjsYtBAeZwpvQYC66k
# 10269  4Q9pUQtb4hx9tf2TjTssE2  spotify:track:4Q9pUQtb4hx9tf2TjTssE2
#
#                                               track_href  \
# 0      https://api.spotify.com/v1/tracks/0ilZMeXHPKDP...
# 1      https://api.spotify.com/v1/tracks/0ZBPWoRkfZ8S...
# 2      https://api.spotify.com/v1/tracks/5sJiLlgQKBL8...
# 3      https://api.spotify.com/v1/tracks/0TN9m8rp3ZuN...
# 4      https://api.spotify.com/v1/tracks/2FrCwt008k0x...
# ...                                                  ...
# 10265  https://api.spotify.com/v1/tracks/2x0eC3SRcTwv...
# 10266  https://api.spotify.com/v1/tracks/0339v0PaMmnp...
# 10267  https://api.spotify.com/v1/tracks/4XjW9fcihP29...
# 10268  https://api.spotify.com/v1/tracks/2yr8zjsYtBAe...
# 10269  https://api.spotify.com/v1/tracks/4Q9pUQtb4hx9...
#
#                                             analysis_url  duration_ms  \
# 0      https://api.spotify.com/v1/audio-analysis/0ilZ...       416027
# 1      https://api.spotify.com/v1/audio-analysis/0ZBP...       262400
# 2      https://api.spotify.com/v1/audio-analysis/5sJi...       244773
# 3      https://api.spotify.com/v1/audio-analysis/0TN9...       484533
# 4      https://api.spotify.com/v1/audio-analysis/2FrC...       369067
# ...                                                  ...          ...
# 10265  https://api.spotify.com/v1/audio-analysis/2x0e...       574615
# 10266  https://api.spotify.com/v1/audio-analysis/0339...       136987
# 10267  https://api.spotify.com/v1/audio-analysis/4XjW...       350573
# 10268  https://api.spotify.com/v1/audio-analysis/2yr8...       319045
# 10269  https://api.spotify.com/v1/audio-analysis/4Q9p...       252760
#
#        time_signature
# 0                   4
# 1                   4
# 2                   4
# 3                   4
# 4                   4
# ...               ...
# 10265               4
# 10266               4
# 10267               4
# 10268               4
# 10269               5
#
# [10270 rows x 18 columns]

# %%
songs_audio_features_dataframe.to_csv("Data/songs_audio_features_cleaned.csv", index=False)
